# %%
import camelot

# %%
tables = camelot.read_pdf('E:\\Microsoft Power BI Cookbook.pdf', pages='132', flavor='stream')

# %%
tables
# Out:
# <TableList n=1>

# %%
tables.export('E:\\test.csv',f='csv',compress=True)

# %%
tables[0]
# Out:
# <Table shape=(27, 3)>

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 96.98, 'whitespace': 49.38, 'order': 1, 'page': 132}

# %%
tables[0].to_csv('E:\\test.csv')

# %%
tables[0].df
# Out:
#                                                     0  \
# 0                                     There's more...
# 1   The following is a list of 11 blogs that conta...
# 2                            BI's tools and features:
# 3                                          Blogger(s)
# 4                                       Michael Carlo
# 5
# 6                                          Chris Webb
# 7
# 8                                          Rob Collie
# 9
# 10                                          Avi Singh
# 11                                    Alberto Ferrari
# 12
# 13                                        Marco Russo
# 14                                    Kasper De Jonge
# 15
# 16                                     Matt Allington
# 17
# 18                                      Ruth Martinez
# 19
# 20                                        Dustin Ryan
# 21
# 22                                           Reza Rad
# 23
# 24                                       Imke Feldman
# ...

# %%
tables.export('E:\\test.json',f='json',compress=True)

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 96.98, 'whitespace': 49.38, 'order': 1, 'page': 132}

# %%
tables[0].to_json('E:\\test.json')

# %%
tables[0].df
# Out:
#                                                     0  \
# 0                                     There's more...
# 1   The following is a list of 11 blogs that conta...
# 2                            BI's tools and features:
# 3                                          Blogger(s)
# 4                                       Michael Carlo
# 5
# 6                                          Chris Webb
# 7
# 8                                          Rob Collie
# 9
# 10                                          Avi Singh
# 11                                    Alberto Ferrari
# 12
# 13                                        Marco Russo
# 14                                    Kasper De Jonge
# 15
# 16                                     Matt Allington
# 17
# 18                                      Ruth Martinez
# 19
# 20                                        Dustin Ryan
# 21
# 22                                           Reza Rad
# 23
# 24                                       Imke Feldman
# ...

# %%
tables.export('E:\\test.html',f='html',compress=True)

# %%
tables[0].to_json('E:\\test.json')

# %%
tables[0].df
# Out:
#                                                     0  \
# 0                                     There's more...
# 1   The following is a list of 11 blogs that conta...
# 2                            BI's tools and features:
# 3                                          Blogger(s)
# 4                                       Michael Carlo
# 5
# 6                                          Chris Webb
# 7
# 8                                          Rob Collie
# 9
# 10                                          Avi Singh
# 11                                    Alberto Ferrari
# 12
# 13                                        Marco Russo
# 14                                    Kasper De Jonge
# 15
# 16                                     Matt Allington
# 17
# 18                                      Ruth Martinez
# 19
# 20                                        Dustin Ryan
# 21
# 22                                           Reza Rad
# 23
# 24                                       Imke Feldman
# ...

# %%
tables.export('E:\\test.xlsx',f='xlsx',compress=True)

# %%
tables[0].to_excel('E:\\test.xlsx')
